# %%
from pydantic import BaseModel, ValidationError
from typing import Optional

class Circle(BaseModel):
    center_x: int = 0
    center_y: int = 0
    radius : int = 1
    name : Optional[str] = None

# %%
Circle.model_fields
# Out:
# {'center_x': FieldInfo(annotation=int, required=False, default=0),
#  'center_y': FieldInfo(annotation=int, required=False, default=0),
#  'radius': FieldInfo(annotation=int, required=False, default=1),
#  'name': FieldInfo(annotation=Union[str, NoneType], required=False, default=None)}

# %%
c1= Circle()

# %%
c1.model_dump()
# Out:
# {'center_x': 0, 'center_y': 0, 'radius': 1, 'name': None}

# %%
c1.model_fields_set
c2= Circle(radius=2)
c2.model_fields_set
# Out:
# {'radius'}

# %%
c2.model_fields.keys() - c2.model_fields_set
# Out:
# /var/folders/qn/bdtm30d94fq_77cy_0tjdzhc0000gn/T/ipykernel_27749/2251699687.py:1: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   c2.model_fields.keys() - c2.model_fields_set
# {'center_x', 'center_y', 'name'}

# %%
c2.model_dump(include=c2.model_fieldsset)
# Out:
# /var/folders/qn/bdtm30d94fq_77cy_0tjdzhc0000gn/T/ipykernel_27749/459772349.py:1: PydanticDeprecatedSince211: Accessing the 'model_fields' attribute on the instance is deprecated. Instead, you should access this attribute from the model class. Deprecated in Pydantic V2.11 to be removed in V3.0.
#   c2.model_dump(include=c2.model_fields.set)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 c2.model_dump(include=c2.model_fields.set)
#
# AttributeError: 'dict' object has no attribute 'set'
